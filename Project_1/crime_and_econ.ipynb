# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#to ignore warnings
import warnings
from functools import reduce
warnings.filterwarnings('ignore')

# %%
#load all the county lists
sc_offenses_2011 = pd.read_csv("Data/SC_County_Offenses_2011 - 11tbl10sc.csv")
sc_offenses_2011 = sc_offenses_2011.dropna()
sc_offenses_2011["Year"] = 2011 #added 'year' column for later data exploration

sc_offenses_2011.dtypes
#have to cast some of the column data into ints from strings

#cast each string(that contains a comma) into a float and then into an int
sc_offenses_2011["Arson"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2011["Arson"]]
sc_offenses_2011["Aggravated assault"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2011["Aggravated assault"]]
sc_offenses_2011["Larceny-theft"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2011["Larceny-theft"]]
sc_offenses_2011["Motor vehicle theft"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2011["Motor vehicle theft"]]
sc_offenses_2011["Property crime"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2011["Property crime"]]
sc_offenses_2011["Violent crime"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2011["Violent crime"]]
sc_offenses_2011["Burglary"] = [int(float(row.replace(',', ''))) for row in sc_offenses_2011["Burglary"]]

sc_offenses_2011.dtypes#checking if it worked
sc_offenses_2011.describe
# Out:
# <bound method NDFrame.describe of    Metropolitan/Nonmetropolitan                          County  \
# 0           Metropolitan County                           Aiken
# 1           Metropolitan County                        Anderson
# 2           Metropolitan County                        Berkeley
# 3           Metropolitan County                         Calhoun
# 4           Metropolitan County                      Charleston
# 5           Metropolitan County                      Darlington
# 6           Metropolitan County                      Dorchester
# 7           Metropolitan County                       Edgefield
# 8           Metropolitan County                       Fairfield
# 9           Metropolitan County                        Florence
# 10          Metropolitan County                      Greenville
# 11          Metropolitan County                           Horry
# 12          Metropolitan County  Horry County Police Department
# ...

# %%
sc_offenses_2012 = pd.read_csv("Data/SC_County_Offenses_2012.csv")
sc_offenses_2012["Year"] = 2012


sc_offenses_2012 = sc_offenses_2012.dropna()
sc_offenses_2012["Year"] = 2012 #added 'year' column for later data exploration

sc_offenses_2012.dtypes
#have to cast some of the column data into ints from strings

#cast each string(that contains a comma) into a float and then into an int
sc_offenses_2012["Arson"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2012["Arson"]]
sc_offenses_2012["Aggravated assault"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2012["Aggravated assault"]]
sc_offenses_2012["Larceny-theft"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2012["Larceny-theft"]]
sc_offenses_2012["Motor vehicle theft"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2012["Motor vehicle theft"]]
sc_offenses_2012["Property crime"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2012["Property crime"]]
sc_offenses_2012["Violent crime"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2012["Violent crime"]]
sc_offenses_2012["Burglary"] = [int(float(row.replace(',', ''))) for row in sc_offenses_2012["Burglary"]]

sc_offenses_2012.dtypes#checking if it worked
sc_offenses_2012.describe
# Out:
# <bound method NDFrame.describe of    Metropolitan/Nonmetropolitan        County  Violent crime  \
# 0           Metropolitan County         Aiken            351
# 1           Metropolitan County      Anderson            809
# 2           Metropolitan County      Beaufort            706
# 3           Metropolitan County      Berkeley            487
# 4           Metropolitan County       Calhoun             53
# 5           Metropolitan County       Chester            110
# 6           Metropolitan County    Darlington            345
# 7           Metropolitan County    Dorchester            345
# 8           Metropolitan County     Edgefield             20
# 9           Metropolitan County     Fairfield            125
# 10          Metropolitan County      Florence            225
# 11          Metropolitan County    Greenville           1994
# 12          Metropolitan County        Jasper             34
# 13          Metropolitan County       Kershaw            256
# ...

# %%
sc_offenses_2013 = pd.read_csv("Data/SC_County_Offenses_2013 - 13tbl10sc.csv")
sc_offenses_2013 = sc_offenses_2013.dropna()
sc_offenses_2013["Year"] = 2013 #added 'year' column for later data exploration

sc_offenses_2013.dtypes
#have to cast some of the column data into ints from strings

#cast each string(that contains a comma) into a float and then into an int
sc_offenses_2013["Arson"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2013["Arson"]]
sc_offenses_2013["Aggravated assault"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2013["Aggravated assault"]]
sc_offenses_2013["Larceny-theft"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2013["Larceny-theft"]]
sc_offenses_2013["Motor vehicle theft"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2013["Motor vehicle theft"]]
sc_offenses_2013["Property crime"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2013["Property crime"]]
sc_offenses_2013["Violent crime"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2013["Violent crime"]]
sc_offenses_2013["Burglary"] = [int(float(row.replace(',', ''))) for row in sc_offenses_2013["Burglary"]]

sc_offenses_2013.dtypes#checking if it worked
sc_offenses_2013.describe
# Out:
# <bound method NDFrame.describe of    Metropolitan/Nonmetropolitan                          County  \
# 0           Metropolitan County                           Aiken
# 1           Metropolitan County                        Anderson
# 2           Metropolitan County                        Beaufort
# 3           Metropolitan County                        Berkeley
# 4           Metropolitan County                         Calhoun
# 5           Metropolitan County                      Charleston
# 6           Metropolitan County                         Chester
# 7           Metropolitan County                      Darlington
# 8           Metropolitan County                      Dorchester
# 9           Metropolitan County                       Edgefield
# 10          Metropolitan County                       Fairfield
# 11          Metropolitan County                        Florence
# 12          Metropolitan County                      Greenville
# ...

# %%
sc_offenses_2014 = pd.read_csv("Data/SC_County_Offenses_2014 - 14tbl10sc.csv")
sc_offenses_2014 = sc_offenses_2014.dropna()
sc_offenses_2014["Year"] = 2014 #added 'year' column for later data exploration

sc_offenses_2014.dtypes
#have to cast some of the column data into ints from strings

#cast each string(that contains a comma) into a float and then into an int
sc_offenses_2014["Arson"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2014["Arson"]]
sc_offenses_2014["Aggravated assault"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2014["Aggravated assault"]]
sc_offenses_2014["Larceny-theft"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2014["Larceny-theft"]]
sc_offenses_2014["Motor vehicle theft"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2014["Motor vehicle theft"]]
sc_offenses_2014["Property crime"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2014["Property crime"]]
sc_offenses_2014["Violent crime"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2014["Violent crime"]]
sc_offenses_2014["Burglary"] = [int(float(row.replace(',', ''))) for row in sc_offenses_2014["Burglary"]]

sc_offenses_2014.dtypes#checking if it worked
sc_offenses_2014.describe
# Out:
# <bound method NDFrame.describe of    Metropolitan/Nonmetropolitan        County  Violent crime  \
# 0           Metropolitan County      Anderson            735
# 1           Metropolitan County      Beaufort            671
# 2           Metropolitan County       Calhoun             33
# 3           Metropolitan County    Charleston            556
# 4           Metropolitan County       Chester            156
# 5           Metropolitan County    Dorchester            321
# 6           Metropolitan County     Fairfield            144
# 7           Metropolitan County      Florence            234
# 8           Metropolitan County    Greenville           2110
# 9           Metropolitan County     Lancaster            300
# 10          Metropolitan County       Laurens            241
# 11          Metropolitan County     Lexington            518
# 12          Metropolitan County       Pickens            230
# 13          Metropolitan County      Richland           1983
# ...

# %%
sc_offenses_2015 = pd.read_csv("Data/SC_County_Offenses_2015 - 15tbl10sc.csv")
sc_offenses_2015 = sc_offenses_2015.dropna()
sc_offenses_2015["Year"] = 2015 #added 'year' column for later data exploration

sc_offenses_2015.dtypes
#have to cast some of the column data into ints from strings

#cast each string(that contains a comma) into a float and then into an int
sc_offenses_2015["Arson"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2015["Arson"]]
sc_offenses_2015["Aggravated assault"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2015["Aggravated assault"]]
sc_offenses_2015["Larceny-theft"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2015["Larceny-theft"]]
sc_offenses_2015["Motor vehicle theft"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2015["Motor vehicle theft"]]
sc_offenses_2015["Property crime"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2015["Property crime"]]
sc_offenses_2015["Violent crime"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2015["Violent crime"]]
sc_offenses_2015["Burglary"] = [int(float(row.replace(',', ''))) for row in sc_offenses_2015["Burglary"]]

sc_offenses_2015.dtypes#checking if it worked
sc_offenses_2015.describe
# Out:
# <bound method NDFrame.describe of    Metropolitan/Nonmetropolitan                          County  \
# 0           Metropolitan County                           Aiken
# 1           Metropolitan County                        Anderson
# 2           Metropolitan County                        Beaufort
# 3           Metropolitan County                        Berkeley
# 4           Metropolitan County                         Calhoun
# 5           Metropolitan County                         Chester
# 6           Metropolitan County                      Dorchester
# 7           Metropolitan County                       Fairfield
# 8           Metropolitan County                        Florence
# 9           Metropolitan County                      Greenville
# 10          Metropolitan County                           Horry
# 11          Metropolitan County  Horry County Police Department
# 12          Metropolitan County                          Jasper
# ...

# %%
sc_offenses_2016 = pd.read_csv("Data/SC_County_Offenses_2016 - 16tbl08sc.csv")

sc_offenses_2016 = sc_offenses_2016.dropna()
sc_offenses_2016["Year"] = 2016 #added 'year' column for later data exploration

sc_offenses_2016.dtypes
#have to cast some of the column data into ints from strings


#cast each string(that contains a comma) into a float and then into an int
sc_offenses_2016["Arson"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2016["Arson"]]
sc_offenses_2016["Aggravated assault"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2016["Aggravated assault"]]
sc_offenses_2016["Larceny-theft"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2016["Larceny-theft"]]
sc_offenses_2016["Motor vehicle theft"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2016["Motor vehicle theft"]]
sc_offenses_2016["Property crime"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2016["Property crime"]]
sc_offenses_2016["Violent crime"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2016["Violent crime"]]
sc_offenses_2016["Burglary"] = [int(float(row.replace(',', ''))) for row in sc_offenses_2016["Burglary"]]

# %%
sc_offenses_2017 = pd.read_csv("Data/SC_County_Offenses_2017 - 17tbl10sc.csv")
sc_offenses_2017 = sc_offenses_2017.dropna()
sc_offenses_2017["Year"] = 2017 #added 'year' column for later data exploration

sc_offenses_2017.dtypes
#have to cast some of the column data into ints from strings

sc_offenses_2017.describe

#cast each string(that contains a comma) into a float and then into an int
sc_offenses_2017["Arson"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2017["Arson"]]
sc_offenses_2017["Aggravated assault"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2017["Aggravated assault"]]
sc_offenses_2017["Larceny-theft"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2017["Larceny-theft"]]
sc_offenses_2017["Motor vehicle theft"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2017["Motor vehicle theft"]]
sc_offenses_2017["Property crime"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2017["Property crime"]]
sc_offenses_2017["Violent crime"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2017["Violent crime"]]
sc_offenses_2017["Burglary"] = [int(float(row.replace(',', ''))) for row in sc_offenses_2017["Burglary"]]
sc_offenses_2017.dtypes
# Out:
# Metropolitan/Nonmetropolitan            object
# County                                  object
# Violent crime                            int64
# Murder and nonnegligent manslaughter     int64
# Forcible rape                            int64
# Robbery                                  int64
# Aggravated assault                       int64
# Property crime                           int64
# Burglary                                 int64
# Larceny-theft                            int64
# Motor vehicle theft                      int64
# Arson                                    int64
# Year                                     int64
# dtype: object

# %%
sc_offenses_2018 = pd.read_csv("Data/SC_County_Offenses_2018 - 18tbl10sc.csv")
sc_offenses_2018 = sc_offenses_2018.dropna()
sc_offenses_2018["Year"] = 2018 #added 'year' column for later data exploration

sc_offenses_2018.dtypes
#have to cast some of the column data into ints from strings

#cast each string(that contains a comma) into a float and then into an int
sc_offenses_2018["Arson"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2018["Arson"]]
sc_offenses_2018["Aggravated assault"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2018["Aggravated assault"]]
sc_offenses_2018["Larceny-theft"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2018["Larceny-theft"]]
sc_offenses_2018["Motor vehicle theft"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2018["Motor vehicle theft"]]
sc_offenses_2018["Property crime"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2018["Property crime"]]
sc_offenses_2018["Violent crime"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2018["Violent crime"]]
sc_offenses_2018["Burglary"] = [int(float(row.replace(',', ''))) for row in sc_offenses_2018["Burglary"]]

sc_offenses_2018.dtypes#checking if it worked
sc_offenses_2018.describe
# Out:
# <bound method NDFrame.describe of    Metropolitan/Nonmetropolitan                          County  \
# 0           Metropolitan County                           Aiken
# 1           Metropolitan County                        Anderson
# 2           Metropolitan County                        Beaufort
# 3           Metropolitan County                        Berkeley
# 4           Metropolitan County                         Calhoun
# 5           Metropolitan County                         Chester
# 6           Metropolitan County                       Clarendon
# 7           Metropolitan County                      Darlington
# 8           Metropolitan County                       Fairfield
# 9           Metropolitan County                        Florence
# 10          Metropolitan County                      Greenville
# 11          Metropolitan County                           Horry
# 12          Metropolitan County  Horry County Police Department
# ...

# %%
sc_offenses_2019 = pd.read_csv("Data/SC_County_Offenses_2019 - 19tbl10sc.csv")
sc_offenses_2019 = sc_offenses_2019.dropna()
sc_offenses_2019["Year"] = 2019 #added 'year' column for later data exploration

sc_offenses_2019.dtypes
#have to cast some of the column data into ints from strings

#cast each string(that contains a comma) into a float and then into an int
sc_offenses_2019["Arson"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2019["Arson"]]
sc_offenses_2019["Aggravated assault"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2019["Aggravated assault"]]
sc_offenses_2019["Larceny-theft"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2019["Larceny-theft"]]
sc_offenses_2019["Motor vehicle theft"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2019["Motor vehicle theft"]]
sc_offenses_2019["Property crime"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2019["Property crime"]]
sc_offenses_2019["Violent crime"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2019["Violent crime"]]
sc_offenses_2019["Burglary"] = [int(float(row.replace(',', ''))) for row in sc_offenses_2019["Burglary"]]

sc_offenses_2019.dtypes#checking if it worked
sc_offenses_2019.shape
# Out:
# (39, 13)

# %% [markdown]
# Since we have dataframes of all the counties for years 2011-2019, it's time to start making dataframes for each county
#
# We will join other county data into these dataframes later

# %%
county_dFrames = [sc_offenses_2011, sc_offenses_2012, sc_offenses_2013, sc_offenses_2014, sc_offenses_2015,
 sc_offenses_2016, sc_offenses_2017, sc_offenses_2018, sc_offenses_2019]

county_count = {}

for frame in county_dFrames:
    for county in frame["County"]:
        if county in county_count:
            county_count[county] += 1
        else:
            county_count[county] = 1

#print(county_dFrames[0].to_dict())

#combine all the dataframes into one
#remove counties that have less than a 9 value count in county_count
sc_offenses = pd.concat(county_dFrames)
sc_offenses = sc_offenses.dropna()
sc_offenses = sc_offenses[sc_offenses["County"].map(county_count) > 8]


type(sc_offenses)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# We're going to focus on the counties that are consistently in all of the dataframes. If they have a value of 9 in the dictionary, they will be usd for study. All else, they will be dropped for this particular study

# %%
personal_income = pd.read_csv("Data\Per capita personal income by county US Dept of Commerce 2011-2021.csv")
#only include the counties that have a value count of 9 or more
personal_income = personal_income[personal_income["County"].map(county_count) > 8]
personal_income = personal_income.dropna()


in_poverty = pd.read_csv("Data\SAIPE Population w percent in poverty 2011-2021_1.csv", encoding = 'latin1')

#take away all columns that are
#list all population columns
pop_columns = [col for col in in_poverty.columns if '%' not in col]
#make a new dataframe with only the population columns
in_poverty_pop = in_poverty[pop_columns]
in_poverty_pop = in_poverty_pop[in_poverty_pop["County"].map(county_count) > 8]
in_poverty_pop = in_poverty_pop.dropna()

per_columns = [col for col in in_poverty.columns if 'Pop.' not in col]
in_poverty_per = in_poverty[per_columns]
in_poverty_per = in_poverty_per[in_poverty_per["County"].map(county_count) > 8]
in_poverty_per = in_poverty_per.dropna()

in_poverty_pop


housing_est = pd.read_csv("Data\Estimated Number of Housing Units 2010-2019 (1).csv",encoding = 'latin1' )
housing_est = housing_est[housing_est["County"].map(county_count) > 8]
housing_est = housing_est.dropna()


med_house_income = pd.read_csv("Data\Median Household Income by County 2011-2021_3.csv", encoding = 'latin1')
med_house_income = med_house_income[med_house_income["County"].map(county_count) > 8]
#add a year column to the dataframe
med_house_income = med_house_income.dropna()



med_house_income

#make an anderson where years are rows and columns from all the dataframes
#add the year column to each dataframe


#make a dictionary where each key is the county name 
county_df_clean = {}
for frame in county_dFrames:
    for county in frame["County"]:
        if county in county_df_clean:
            county_df_clean[county].append(frame)
        else:
            county_df_clean[county] = [frame]

# %% [markdown]
# WE now have two merged dataframes to work with- one for each county(that has data for all years 2011-2019) and a master dataframe of financial data with the same type of schema.
#
# Since we have cleaned each dataframe, the final step before analysis is formatting of the frames

# %% [markdown]
# Analysis Time

# %%
med_house_income = med_house_income.reset_index(drop=True)

# %%
sc_offenses = sc_offenses.reset_index(drop=True)

# %%
sc_offenses
# Out:
#     Metropolitan/Nonmetropolitan      County  Violent crime  \
# 0            Metropolitan County    Anderson            776
# 1            Metropolitan County     Calhoun             57
# 2            Metropolitan County   Fairfield            120
# 3            Metropolitan County    Florence            276
# 4            Metropolitan County  Greenville           1819
# ..                           ...         ...            ...
# 184       Nonmetropolitan County     Hampton             61
# 185       Nonmetropolitan County         Lee             64
# 186       Nonmetropolitan County    Newberry             91
# 187       Nonmetropolitan County      Oconee            199
# 188       Nonmetropolitan County       Union             53
#
#      Murder and nonnegligent manslaughter  Forcible rape Robbery  \
# 0                                      11             46      84
# 1                                       1              2       6
# ...

# %%
med_house_income
# Out:
#          County    2011    2012    2013    2014    2015    2016    2017  \
# 0      Anderson  41,000  39,905  41,591  43,124  44,745  45,821  48,846
# 1       Bamberg  28,467  30,170  30,762  30,349  29,642  32,245  32,693
# 2      Barnwell  33,178  32,042  31,899  32,205  33,280  41,803  36,568
# 3       Calhoun  38,417  42,006  40,593  41,209  41,277  41,786  45,149
# 4       Chester  32,857  33,718  36,523  37,537  35,006  39,972  40,850
# 5     Clarendon  30,780  30,519  30,096  32,268  34,654  34,541  36,647
# 6        Dillon  26,308  29,205  33,696  30,516  31,094  31,761  32,229
# 7     Fairfield  34,700  34,007  35,531  35,490  36,622  36,715  40,285
# 8      Florence  39,663  40,577  41,028  42,232  41,197  45,044  43,727
# 9    Greenville  48,480  47,044  49,476  49,659  52,017  55,452  56,311
# 10      Hampton  31,915  32,934  32,941  33,644  30,772  35,667  36,834
# 11    Lancaster  40,372  43,479  40,837  44,854  47,279  53,421  57,667
# ...

# %%
#making anderson offense df
anderson_offenses = sc_offenses.query('County == "Anderson"').drop(columns="Metropolitan/Nonmetropolitan").reset_index(drop=True)

# %%
#making anderson med_house_income df
anderson_med_house_income = med_house_income.query('County == "Anderson"').reset_index(drop=True)

# %%
anderson_offenses
# Out:
#      County  Violent crime  Murder and nonnegligent manslaughter  \
# 0  Anderson            776                                    11
# 1  Anderson            809                                    10
# 2  Anderson            803                                     8
# 3  Anderson            735                                     8
# 4  Anderson            752                                    18
# 5  Anderson            918                                    16
# 6  Anderson            738                                     8
# 7  Anderson            740                                    13
# 8  Anderson            693                                    12
#
#    Forcible rape Robbery  Aggravated assault  Property crime  Burglary  \
# 0             46      84                 635            6900      2061
# 1             40     110                 649            6816      1890
# 2             63     142                 590            7617      2169
# ...

# %%
anderson_med_house_income = anderson_med_house_income.rename(columns={"County":"Year"})

# %%
anderson_med_house_income.T
# Out:
#              0
# Year  Anderson
# 2011    41,000
# 2012    39,905
# 2013    41,591
# 2014    43,124
# 2015    44,745
# 2016    45,821
# 2017    48,846
# 2018    51,740
# 2019    54,496

# %%
#combine anderson_offenses and anderson_med_house_income on the year column
anderson_offenses["Year"] = anderson_offenses["Year"].astype(str)
anderson_med_house_income["Year"] = anderson_med_house_income["Year"].astype(str)

# %%
#check the columns of each df

print(anderson_offenses.columns, "\n","Med income columns: ", anderson_med_house_income.columns)
# Out:
# Index(['County', 'Violent crime', 'Murder and nonnegligent manslaughter',
#        'Forcible rape', 'Robbery', 'Aggravated assault', 'Property crime',
#        'Burglary', 'Larceny-theft', 'Motor vehicle theft', 'Arson', 'Year',
#        'Median household income'],
#       dtype='object')
#  Med income columns:  Index(['Year', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019'],
#       dtype='object')

# %%
#get row 2 of anderson_med_house_income
#a = anderson_med_house_income.T.iloc[0].astype(str)

tex = anderson_med_house_income.T.iloc[1].astype(str)

tex.to_list()

str(tex[0])

dat = []
year = 2011

max = 9
while max > 0:
    numbs = anderson_med_house_income.T.iloc[max].astype(str)
    nums = numbs.to_list()
    dat.append(str(nums[0]))
    
    max -= 1

dat
# Out:
# ['54,496',
#  '51,740',
#  '48,846',
#  '45,821',
#  '44,745',
#  '43,124',
#  '41,591',
#  '39,905',
#  '41,000']

# %%
dat = pd.DataFrame(dat, columns=["Med_House_Income"])
anderson_full = pd.concat([anderson_offenses, dat], axis=1, join='inner').drop(columns="Median household income")

# %%
anderson_full
# Out:
#      County  Violent crime  Murder and nonnegligent manslaughter  \
# 0  Anderson            776                                    11
# 1  Anderson            809                                    10
# 2  Anderson            803                                     8
# 3  Anderson            735                                     8
# 4  Anderson            752                                    18
# 5  Anderson            918                                    16
# 6  Anderson            738                                     8
# 7  Anderson            740                                    13
# 8  Anderson            693                                    12
#
#    Forcible rape Robbery  Aggravated assault  Property crime  Burglary  \
# 0             46      84                 635            6900      2061
# 1             40     110                 649            6816      1890
# 2             63     142                 590            7617      2169
# ...
