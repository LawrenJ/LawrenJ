# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#to ignore warnings
import warnings
from functools import reduce
warnings.filterwarnings('ignore')

# %%
#load all the county lists
sc_offenses_2011 = pd.read_csv("Data/SC_County_Offenses_2011 - 11tbl10sc.csv")
sc_offenses_2011 = sc_offenses_2011.dropna()
sc_offenses_2011["Year"] = 2011

sc_offenses_2011.dtypes
#have to cast some of the column data into ints from strings

for row in sc_offenses_2011["Arson"]:
    row = int(row)

#cast each string(that contains a comma) into a float and then into an int
sc_offenses_2011["Arson"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2011["Arson"]]
sc_offenses_2011["Aggravated assault"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2011["Aggravated assault"]]
sc_offenses_2011["Larceny-theft"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2011["Larceny-theft"]]
sc_offenses_2011["Motor vehicle theft"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2011["Motor vehicle theft"]]
sc_offenses_2011["Property crime"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2011["Property crime"]]
sc_offenses_2011["Violent crime"] = [int(float(str(row).replace(',',''))) for row in sc_offenses_2011["Violent crime"]]

sc_offenses_2011.dtypes

#sc_offenses_2011["Aggravated \nassault"] = [int(row) for row in sc_offenses_2011["Aggravated \nassault"]]

sc_offenses_2011["Burglary"] = [int(float(row.replace(',', ''))) for row in sc_offenses_2011["Burglary"]]

sc_offenses_2011
# Out:
#    Metropolitan/Nonmetropolitan                          County  \
# 0           Metropolitan County                           Aiken
# 1           Metropolitan County                        Anderson
# 2           Metropolitan County                        Berkeley
# 3           Metropolitan County                         Calhoun
# 4           Metropolitan County                      Charleston
# 5           Metropolitan County                      Darlington
# 6           Metropolitan County                      Dorchester
# 7           Metropolitan County                       Edgefield
# 8           Metropolitan County                       Fairfield
# 9           Metropolitan County                        Florence
# 10          Metropolitan County                      Greenville
# 11          Metropolitan County                           Horry
# 12          Metropolitan County  Horry County Police Department
# 13          Metropolitan County                         Kershaw
# ...

# %%
sc_offenses_2012 = pd.read_csv("Data/SC_County_Offenses_2012.csv")
sc_offenses_2012["Year"] = 2012

# %%
sc_offenses_2013 = pd.read_csv("Data/SC_County_Offenses_2013 - 13tbl10sc.csv")
sc_offenses_2013["Year"] = 2013

# %%
sc_offenses_2014 = pd.read_csv("Data/SC_County_Offenses_2014 - 14tbl10sc.csv")
sc_offenses_2014["Year"] = 2014

# %%
sc_offenses_2015 = pd.read_csv("Data/SC_County_Offenses_2015 - 15tbl10sc.csv")
sc_offenses_2015["Year"] = 2015

# %%
sc_offenses_2016 = pd.read_csv("Data/SC_County_Offenses_2016 - 16tbl08sc.csv")
sc_offenses_2016["Year"] = 2016

# %%
sc_offenses_2017 = pd.read_csv("Data/SC_County_Offenses_2017 - 17tbl10sc.csv")
sc_offenses_2017["Year"] = 2017

# %%
sc_offenses_2018 = pd.read_csv("Data/SC_County_Offenses_2018 - 18tbl10sc.csv")
sc_offenses_2018["Year"] = 2018

# %%
sc_offenses_2019 = pd.read_csv("Data/SC_County_Offenses_2019 - 19tbl10sc.csv")
sc_offenses_2019["Year"] = 2019



#aiken_list = [sc_offenses_2011.loc[sc_offenses_2011["County"] == "Aiken"], sc_offenses_2012.loc[sc_offenses_2012["County"] == "Aiken"],
               #sc_offenses_2013.loc[sc_offenses_2013["County"] == "Aiken"]]


#df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['County'], how='outer'), aiken_list)

# %%
personal_income = pd.read_csv("Data\Per capita personal income by county US Dept of Commerce 2011-2021.csv")
personal_income.head()
personal_income.tail()
# Out:
#    Per Capita Personal Income by County 2011-2021 Unnamed: 1 Unnamed: 2  \
# 43                                    Spartanburg    $33,896    $36,130
# 44                                         Sumter    $31,784    $33,322
# 45                                          Union    $26,909    $27,393
# 46                                   Williamsburg    $26,660    $25,976
# 47                                           York    $36,133    $38,320
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 43    $35,059    $37,946    $39,458    $40,784    $41,352    $42,141
# 44    $33,405    $34,591    $35,526    $36,368    $37,576    $38,876
# 45    $27,550    $28,802    $29,875    $29,708    $30,917    $32,245
# 46    $26,881    $27,811    $28,401    $29,370    $30,407    $31,362
# 47    $38,367    $40,220    $42,159    $44,100    $46,139    $47,853
#
#    Unnamed: 9  ... Unnamed: 13 Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# ...

# %%
in_poverty = pd.read_csv("Data\SAIPE Population w percent in poverty 2011-2021_1.csv", encoding = 'latin1')
in_poverty.head()
in_poverty.tail()
in_poverty.describe()
# Out:
#        Population with Percent in Poverty by County 2011-2021 Unnamed: 1  \
# count                                                  48             49
# unique                                                 48             49
# top                                                County           2011
# freq                                                    1              1
#
#        Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# count          48         49         48         49         48         49
# unique         41         49         44         49         43         49
# top        20.20%       2012     25.20%       2013     18.70%       2014
# freq            2          1          2          1          3          1
#
#        Unnamed: 8 Unnamed: 9  ... Unnamed: 13 Unnamed: 14 Unnamed: 15  \
# count          48         49  ...          49          48          49
# unique         44         49  ...          49          43          49
# ...

# %%
housing_est = pd.read_csv("Data\Estimated Number of Housing Units 2010-2019 (1).csv",encoding = 'latin1' )
housing_est.head()
housing_est.tail()
housing_est.describe()
# Out:
#                 County       2010       2011       2012       2013       2014  \
# count               47         47         47         47         47         47
# unique              47         47         47         47         47         47
# top     South Carolina  2,140,804  2,151,618  2,164,113  2,179,880  2,201,469
# freq                 1          1          1          1          1          1
#
#              2015       2016       2017       2018       2019
# count          47         47         47         47         47
# unique         47         47         47         47         47
# top     2,225,969  2,254,296  2,284,232  2,318,035  2,351,286
# freq            1          1          1          1          1

# %%
med_house_incomme = pd.read_csv("Data\Median Household Income by County 2011-2021_3.csv", encoding = 'latin1')
med_house_incomme.head()
# Out:
#            County      2011      2012      2013      2014      2015      2016  \
# 0  South Carolina  $42,477   $43,290   $44,310   $45,337   $47,308   $49,587
# 1       Abbeville  $36,787   $35,456   $36,187   $35,525   $35,932   $40,211
# 2           Aiken  $42,826   $45,699   $43,876   $48,537   $48,012   $47,394
# 3       Allendale  $24,820   $25,633   $25,753   $25,530   $27,089   $26,864
# 4        Anderson  $41,000   $39,905   $41,591   $43,124   $44,745   $45,821
#
#        2017      2018      2019      2020      2021
# 0  $50,675   $52,449   $56,360   $57,216   $59,447
# 1  $41,118   $42,412   $46,499   $47,219   $49,485
# 2  $51,583   $52,633   $56,824   $57,128   $56,711
# 3  $28,135   $29,124   $32,147   $32,701   $31,262
# 4  $48,846   $51,740   $54,496   $52,667   $58,951

# %%
count_labor = pd.read_csv("Data\SC_County_Laborforce.csv", encoding = 'latin1')
count_labor.head()
# Out:
#   Unemployment Rates by County 2012-2022  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0                                 County      2012.0      2013.0      2014.0
# 1               South Carolina Statewide         4.0         7.4         6.3
# 2                              Abbeville         4.5         9.3         7.5
# 3                                  Aiken         3.4         7.4         6.3
# 4                              Allendale         7.8        13.7        11.9
#
#    Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0      2015.0      2016.0      2017.0      2018.0      2019.0      2020.0
# 1         5.9         4.9         4.2         3.4         2.8         6.0
# 2         6.8         5.4         4.5         3.9         3.3         6.5
# 3         5.8         4.9         4.0         3.3         2.8         4.9
# 4        11.2         8.4         6.8         5.6         5.2         9.3
#
# ...

# %%
#personal_income.head()
personal_income.tail(3)
# Out:
#    Per Capita Personal Income by County 2011-2021 Unnamed: 1 Unnamed: 2  \
# 45                                          Union    $26,909    $27,393
# 46                                   Williamsburg    $26,660    $25,976
# 47                                           York    $36,133    $38,320
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 45    $27,550    $28,802    $29,875    $29,708    $30,917    $32,245
# 46    $26,881    $27,811    $28,401    $29,370    $30,407    $31,362
# 47    $38,367    $40,220    $42,159    $44,100    $46,139    $47,853
#
#    Unnamed: 9  ... Unnamed: 13 Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# 45    $34,503  ...         NaN         NaN          NaN          NaN
# 46    $33,664  ...         NaN         NaN          NaN          NaN
# 47    $50,047  ...         NaN         NaN          NaN          NaN
#
#     Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# ...
